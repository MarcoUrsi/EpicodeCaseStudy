# %%
#1

# %%
import pandas as pd

# %%
amazon = pd.read_csv("amazon.csv")

# %%
amazon.shape
# Out:
# (20000, 2)

# %%
amazon.columns
# Out:
# Index(['TestoRecensione', 'Valutazione'], dtype='object')

# %%
amazon.head(10)
# Out:
#                                      TestoRecensione  Valutazione
# 0  This is a one of the best apps acording to a b...            1
# 1  This is a pretty good version of the game for ...            1
# 2  this is a really cool game. there are a bunch ...            1
# 3  This is a silly game and can be frustrating, b...            1
# 4  This is a terrific game on any pad. Hrs of fun...            1
# 5  This is a very entertaining game!  You don't h...            1
# 6  this is awesome and you don't need wi ti to pl...            1
# 7  this is awesome I bet no one even reads the re...            1
# 8  This is basicly the free version but with ads....            1
# 9  this is by far the best free app that is avail...            1

# %%
amazon.sample(10)
# Out:
#                                          TestoRecensione  Valutazione
# 11572  I was considering replacing my Kindle Fire wit...            1
# 214    This was fun. It took a while to know certain ...            1
# 14728  I haven't even bought this game and I'm grosse...            0
# 13618  why would you need a note calender....? can't ...            0
# 9336   AS AN UPDATE, my last review (below) was Octob...            0
# 10818  This is a good app.  I can increase and decrea...            1
# 9205   When Vevo first appeared as an app on my Roku,...            1
# 4895   Any calculator I use must have the +/- key and...            1
# 9643   Aldiko is the best e-book reader I have found ...            1
# 921    This one is fun and after each match 3 or more...            1

# %%
amazon.rename(columns={"reviewText": "TestoRecensione",
              "Valutazione(bool)": "Valutazione"},
              inplace=True)

# %%
amazon
# Out:
#                                          TestoRecensione  Valutazione
# 0      This is a one of the best apps acording to a b...            1
# 1      This is a pretty good version of the game for ...            1
# 2      this is a really cool game. there are a bunch ...            1
# 3      This is a silly game and can be frustrating, b...            1
# 4      This is a terrific game on any pad. Hrs of fun...            1
# ...                                                  ...          ...
# 19995  this app is fricken stupid.it froze on the kin...            0
# 19996  Please add me!!!!! I need neighbors! Ginger101...            1
# 19997  love it!  this game. is awesome. wish it had m...            1
# 19998  I love love love this app on my side of fashio...            1
# 19999  This game is a rip off. Here is a list of thin...            0
#
# [20000 rows x 2 columns]

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TestoRecensione  20000 non-null  object
#  1   Valutazione      20000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 312.6+ KB

# %%
amazon.describe()
# Out:
#         Valutazione
# count  20000.000000
# mean       0.761650
# std        0.426085
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
query1 = amazon.groupby("Valutazione")

# %%
positivi = query1.get_group(1)

# %%
positivi
# Out:
#                                          TestoRecensione  Valutazione
# 0      This is a one of the best apps acording to a b...            1
# 1      This is a pretty good version of the game for ...            1
# 2      this is a really cool game. there are a bunch ...            1
# 3      This is a silly game and can be frustrating, b...            1
# 4      This is a terrific game on any pad. Hrs of fun...            1
# ...                                                  ...          ...
# 19992  I love this app! cant get enough of it. its al...            1
# 19993  If I could rate 1,000,000,000,000,000,000,000 ...            1
# 19996  Please add me!!!!! I need neighbors! Ginger101...            1
# 19997  love it!  this game. is awesome. wish it had m...            1
# 19998  I love love love this app on my side of fashio...            1
#
# [15233 rows x 2 columns]

# %%
negativi = query1.get_group(0)

# %%
negativi
# Out:
#                                          TestoRecensione  Valutazione
# 78     They call it three next mario??? Are the 'prof...            0
# 79     Angry People in my book!  Any moron who would ...            0
# 80     Argry Birds is for free to play a games on you...            0
# 81     cant stand this game. love the concept and pla...            0
# 82     Don't really know the point of this game.  It'...            0
# ...                                                  ...          ...
# 19969  I love TeamLava. This game sucked. Horrible, e...            0
# 19973  this app always closes when I'm invite it alwa...            0
# 19994  I hate it! I barely played it for 40 sec. befo...            0
# 19995  this app is fricken stupid.it froze on the kin...            0
# 19999  This game is a rip off. Here is a list of thin...            0
#
# [4767 rows x 2 columns]

# %%
valutazionebool = amazon.Valutazione

# %%
valutazionebool.value_counts()
# Out:
# 1    15233
# 0     4767
# Name: Valutazione, dtype: int64

# %%
amazon.Valutazione.value_counts()
# Out:
# 1    15233
# 0     4767
# Name: Valutazione, dtype: int64

# %%
filtroapp = amazon.TestoRecensione.str.contains("app")

# %%
amazon.loc[filtroapp]
# Out:
#                                          TestoRecensione  Valutazione
# 0      This is a one of the best apps acording to a b...            1
# 6      this is awesome and you don't need wi ti to pl...            1
# 9      this is by far the best free app that is avail...            1
# 14     this is one of the best apps in the world alon...            1
# 17     This is the best app ever. It makes it way eas...            1
# ...                                                  ...          ...
# 19983  I love this game so much that I play it every ...            1
# 19992  I love this app! cant get enough of it. its al...            1
# 19993  If I could rate 1,000,000,000,000,000,000,000 ...            1
# 19995  this app is fricken stupid.it froze on the kin...            0
# 19998  I love love love this app on my side of fashio...            1
#
# [9297 rows x 2 columns]

# %%
print(amazon[amazon["TestoRecensione"].str.contains("app")])
# Out:
#                                          TestoRecensione  Valutazione
# 0      This is a one of the best apps acording to a b...            1
# 6      this is awesome and you don't need wi ti to pl...            1
# 9      this is by far the best free app that is avail...            1
# 14     this is one of the best apps in the world alon...            1
# 17     This is the best app ever. It makes it way eas...            1
# ...                                                  ...          ...
# 19983  I love this game so much that I play it every ...            1
# 19992  I love this app! cant get enough of it. its al...            1
# 19993  If I could rate 1,000,000,000,000,000,000,000 ...            1
# 19995  this app is fricken stupid.it froze on the kin...            0
# 19998  I love love love this app on my side of fashio...            1
#
# [9297 rows x 2 columns]

# %%
amazon[amazon["TestoRecensione"].str.contains("app")].value_counts()
# Out:
# TestoRecensione                                                                                                                                                                                                                                                 Valutazione
# "Calculator Ultimate" is an outstanding calculator app. The scientific functions are exactly what I was looking for and it has a great, easy to use layout. The addition of a unit converter (which gets a lot of use) makes this a real winner!Installed and   1              1
# This app sucks. It is very inaccurate, and it only tests you on recognizing patterns. I wasn't expecting much, but this was worse than expected.                                                                                                                0              1
# ...

# %%
filtrogame = amazon.TestoRecensione.str.contains("game")

# %%
amazon.loc[filtrogame]
# Out:
#                                          TestoRecensione  Valutazione
# 1      This is a pretty good version of the game for ...            1
# 2      this is a really cool game. there are a bunch ...            1
# 3      This is a silly game and can be frustrating, b...            1
# 4      This is a terrific game on any pad. Hrs of fun...            1
# 5      This is a very entertaining game!  You don't h...            1
# ...                                                  ...          ...
# 19991  great interactive game love playing it and so ...            1
# 19995  this app is fricken stupid.it froze on the kin...            0
# 19996  Please add me!!!!! I need neighbors! Ginger101...            1
# 19997  love it!  this game. is awesome. wish it had m...            1
# 19999  This game is a rip off. Here is a list of thin...            0
#
# [4661 rows x 2 columns]

# %%
print(amazon[amazon["TestoRecensione"].str.contains("game")])
# Out:
#                                          TestoRecensione  Valutazione
# 1      This is a pretty good version of the game for ...            1
# 2      this is a really cool game. there are a bunch ...            1
# 3      This is a silly game and can be frustrating, b...            1
# 4      This is a terrific game on any pad. Hrs of fun...            1
# 5      This is a very entertaining game!  You don't h...            1
# ...                                                  ...          ...
# 19991  great interactive game love playing it and so ...            1
# 19995  this app is fricken stupid.it froze on the kin...            0
# 19996  Please add me!!!!! I need neighbors! Ginger101...            1
# 19997  love it!  this game. is awesome. wish it had m...            1
# 19999  This game is a rip off. Here is a list of thin...            0
#
# [4661 rows x 2 columns]

# %%
print(amazon[amazon["TestoRecensione"].str.contains("kindle")])
# Out:
#                                          TestoRecensione  Valutazione
# 11     this. is fun an time consuming. works great on...            1
# 15     This is super fun though a little frustrating ...            1
# 32     This physics based game is perfect for people ...            1
# 33     This seems to be popular when my kindle fire i...            1
# 37     this was one of the first apps I got on my kin...            1
# ...                                                  ...          ...
# 19941  i got this game on my iphone, then on my kindl...            1
# 19974  I love this app so so much best app ever inven...            1
# 19988  its a really fun game to play and I love going...            1
# 19994  I hate it! I barely played it for 40 sec. befo...            0
# 19995  this app is fricken stupid.it froze on the kin...            0
#
# [1356 rows x 2 columns]

# %%
amazon.TestoRecensione.str.contains("kindle").sum()
# Out:
# 1356

# %%
print(amazon[amazon["TestoRecensione"].str.contains("Kindle")])
# Out:
#                                          TestoRecensione  Valutazione
# 24     This is the first app that I installed onKindl...            1
# 29     This is the original anfry birds game but it o...            1
# 34     This so much fun! My daughter has vthis app fo...            1
# 38     This was the 1st app I ever downloaded on my K...            1
# 49     We downloaded the free version for our tween's...            1
# ...                                                  ...          ...
# 19873  I play this on my Kindle Fire HD 7 inch screen...            1
# 19884  Kindle Fire - I didn't even play this game.  I...            0
# 19903  Kindle Fire User. I love the game. You do NOT ...            1
# 19906  Great knowing that your kids know how hard a f...            1
# 19913  I have always liked this game, I play it on my...            1
#
# [1328 rows x 2 columns]

# %%
filtro1 = amazon.TestoRecensione.str.contains("kindle")
filtro2 = amazon.TestoRecensione.str.contains("Kindle")

# %%
filtro = filtro1 | filtro2

# %%
filtro.sum()
# Out:
# 2663

# %%
#sono di piu perche appaiono due volte nella stringa, spra or
filtro1.sum() + filtro2.sum()
# Out:
# 2684

# %%
def minuscolo(testo):
    return testo.lower()

# %%
for review in amazon.TestoRecensione.iloc[:5]:
    print("-", review, "\n")
# Out:
# - This is a one of the best apps acording to a bunch of people and I agree it has bombs eggs pigs TNT king pigs and realustic stuff
#
# - This is a pretty good version of the game for being free. There are LOTS of different levels to play. My kids enjoy it a lot too.
#
# - this is a really cool game. there are a bunch of levels and you can find golden eggs. super fun.
#
# - This is a silly game and can be frustrating, but lots of fun and definitely recommend just as a fun time.
#
# - This is a terrific game on any pad. Hrs of fun.  My grandkids love it. Great entertainment when waiting in long lines

# %%
for review in amazon.TestoRecensione.apply(minuscolo).iloc[:5]:
    print("-", review, "\n")
# Out:
# - this is a one of the best apps acording to a bunch of people and i agree it has bombs eggs pigs tnt king pigs and realustic stuff
#
# - this is a pretty good version of the game for being free. there are lots of different levels to play. my kids enjoy it a lot too.
#
# - this is a really cool game. there are a bunch of levels and you can find golden eggs. super fun.
#
# - this is a silly game and can be frustrating, but lots of fun and definitely recommend just as a fun time.
#
# - this is a terrific game on any pad. hrs of fun.  my grandkids love it. great entertainment when waiting in long lines

# %%
amazon.loc[:,"reviewTestoRecensione"] = [amazon.TestoRecensione[:].apply(minuscolo)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 amazon.loc[:,"reviewTestoRecensione"] = [amazon.TestoRecensione[:].apply(minuscolo)]
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# ...

# %%
for review in amazon.loc[filtro].iloc[:10 "TestoRecensione"]:
    print(review)
# Out:
#   Cell In[74], line 1
#     for review in amazon.loc[filtro].iloc[:10 "TestoRecensione"]:
#                                            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
for review in amazon.loc[filtro].iloc[:10].loc[:,"TestoRecensione"]:
    print(review, "\n")
# Out:
# this. is fun an time consuming. works great on my kindle fire I really like this game so does my btother
#
# This is super fun though a little frustrating at times!!!!!!!!! I loved it before I got my kindle I would beg my brother and dad to play. But when I get it I play it all the time!!!!!!
#
# This is the first app that I installed onKindle Fire, Full Color 7" Multi-touch Display, Wi-Fiwhich I purchased recently from Amazon. Angry Birds (free version) works smoothly on Kindle fire.Love the smooth graphics! It responds perfectly and It is a ple
#
# This is the original anfry birds game but it only works on the original Kindle Fire and not on the new HD version.NEW NOTE - This has now been updated to work on the new Kindle Fire HD. Of course that did not happen until I bought the paid version, but n
#
# This physics based game is perfect for people of all ages to spend extra time on a mobile device. Yet it still offers some challenge. It works very well on the kindle fire.
#
# ...

# %%
frase = "I love mi Kindle, my kinDle is awesome"

# %%
frase.lower().count("kindle")
# Out:
# 2

# %%
general_kindle = frase.lower().count("kindle")

# %%
target_kindle = frase

# %%
#10 a caso
for review in amazon.loc[filtro].sample(10).loc[:,"TestoRecensione"]:
    print(review, "\n")
# Out:
# great app to have on your kindle if you wanted something other then amazons browser get the maxthon its great
#
# Great!!!!! So glad I put this on my Kindle. I use it much more now than I ever did on my iPhone.
#
# This is a must get funniest most destructive game out the 5/5* funniest game ive played on kindle. So stop reading reveiws and get it!
#
# I've been using Plex for awhile now on my pc and Roku player, but decided to give it a go on the new kindle fire HD. I love the responsiveness and speed off it and how clear it is as well. Totally worth the cost.
#
# Don't waste your time with this.  I only have a kindle and looking at the website without this app is much better.  There are limited graphics and options with it.
#
# I loved this game growning up in Texas, Now its on my Kindle soooo happy I got it. Get it!
#
# ...

# %%
amazon1 = amazon.loc[filtro]

# %%
amazon1
# Out:
#                                          TestoRecensione  Valutazione
# 0      This is a one of the best apps acording to a b...            1
# 6      this is awesome and you don't need wi ti to pl...            1
# 9      this is by far the best free app that is avail...            1
# 14     this is one of the best apps in the world alon...            1
# 17     This is the best app ever. It makes it way eas...            1
# ...                                                  ...          ...
# 19983  I love this game so much that I play it every ...            1
# 19992  I love this app! cant get enough of it. its al...            1
# 19993  If I could rate 1,000,000,000,000,000,000,000 ...            1
# 19995  this app is fricken stupid.it froze on the kin...            0
# 19998  I love love love this app on my side of fashio...            1
#
# [9297 rows x 2 columns]

# %%
amazon1.Valutazione.value_counts(), print("le recensioni che menzionano Kindle positive sono: 6973 e negative: 2324")
# Out:
# le recensioni che menzionano Kindle positive sono: 6973 e negative: 2324
# (1    6973
#  0    2324
#  Name: Valutazione, dtype: int64,
#  None)

# %%
#2

# %%
pazienti = pd.read_csv("diabetes.csv")

# %%
pazienti.rename(columns={"Age (years)": "Eta",
             "Diastolic blood pressure (mm Hg)": "PressioneSanguignaDiastolica"},
              inplace=True)

# %%
pazienti.shape
# Out:
# (768, 9)

# %%
pazienti
# Out:
#      Number of times pregnant  \
# 0                           6
# 1                           1
# 2                           8
# 3                           1
# 4                           0
# ..                        ...
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 1                                                   85
# 2                                                  183
# 3                                                   89
# 4                                                  137
# ..                                                 ...
# 763                                                101
# 764                                                122
# 765                                                121
# ...

# %%
pazienti.sample(10)
# Out:
#      Number of times pregnant  \
# 165                         6
# 107                         4
# 422                         0
# 204                         6
# 139                         5
# 629                         4
# 267                         2
# 652                         5
# 210                         2
# 499                         6
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 165                                                104
# 107                                                144
# 422                                                102
# 204                                                103
# 139                                                105
# 629                                                 94
# 267                                                128
# 652                                                123
# 210                                                 81
# ...

# %%
pazienti.describe()
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        PressioneSanguignaDiastolica  Triceps skin fold thickness (mm)  \
# ...

# %%
filtro20 = pazienti.loc[:,"Eta"] <= 20

# %%
pazienti.loc[filtro20]
# Out:
# Empty DataFrame
# Columns: [Number of times pregnant, Plasma glucose concentration a 2 hours in an oral glucose tolerance test, PressioneSanguignaDiastolica, Triceps skin fold thickness (mm), 2-Hour serum insulin (mu U/ml), Body mass index (weight in kg/(height in m)^2), Diabetes pedigree function, Eta, Class variable]
# Index: []

# %%
filtro1_20_30 = pazienti.loc[:,"Eta"] >= 20

# %%
filtro2_20_30 = pazienti.loc[:,"Eta"] < 30

# %%
filtro20_30 = filtro1_20_30 & filtro2_20_30

# %%
pazienti.loc[filtro20_30]
# Out:
#      Number of times pregnant  \
# 3                           1
# 6                           3
# 7                          10
# 20                          3
# 23                          9
# ..                        ...
# 753                         0
# 758                         1
# 760                         2
# 764                         2
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 3                                                   89
# 6                                                   78
# 7                                                  115
# 20                                                 126
# 23                                                 119
# ..                                                 ...
# 753                                                181
# 758                                                106
# 760                                                 88
# ...

# %%
pazienti.loc[filtro20_30].mean()
# Out:
# Number of times pregnant                                                      1.921717
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test    113.744949
# PressioneSanguignaDiastolica                                                 65.348485
# Triceps skin fold thickness (mm)                                             21.949495
# 2-Hour serum insulin (mu U/ml)                                               84.393939
# Body mass index (weight in kg/(height in m)^2)                               31.390404
# Diabetes pedigree function                                                    0.451048
# Eta                                                                          24.313131
# Class variable                                                                0.212121
# dtype: float64

# %%
filtro1_30_40 = pazienti.loc[:,"Eta"] >= 30
filtro2_30_40 = pazienti.loc[:,"Eta"] < 40

# %%
filtro30_40 = filtro1_30_40 & filtro2_30_40

# %%
pazienti.loc[filtro30_40]
# Out:
#      Number of times pregnant  \
# 1                           1
# 2                           8
# 4                           0
# 5                           5
# 10                          4
# ..                        ...
# 748                         3
# 755                         1
# 756                         7
# 762                         9
# 765                         5
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 1                                                   85
# 2                                                  183
# 4                                                  137
# 5                                                  116
# 10                                                 110
# ..                                                 ...
# 748                                                187
# 755                                                128
# 756                                                137
# ...

# %%
filtro1_40_50 = pazienti.loc[:,"Eta"] >= 40
filtro2_40_50 = pazienti.loc[:,"Eta"] < 50

# %%
filtro40_50 = filtro1_40_50 & filtro2_40_50

# %%
pazienti.loc[filtro40_50]
# Out:
#      Number of times pregnant  \
# 22                          7
# 25                         10
# 26                          7
# 34                         10
# 37                          9
# ..                        ...
# 743                         9
# 745                        12
# 754                         8
# 761                         9
# 766                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 22                                                 196
# 25                                                 125
# 26                                                 147
# 34                                                 122
# 37                                                 102
# ..                                                 ...
# 743                                                140
# 745                                                100
# 754                                                154
# ...

# %%
filtro50 = pazienti.loc[:,"Eta"] >= 50

# %%
pazienti.loc[filtro50]
# Out:
#      Number of times pregnant  \
# 0                           6
# 8                           2
# 9                           8
# 12                         10
# 13                          1
# ..                        ...
# 734                         2
# 749                         6
# 757                         0
# 759                         6
# 763                        10
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 8                                                  197
# 9                                                  125
# 12                                                 139
# 13                                                 189
# ..                                                 ...
# 734                                                105
# 749                                                162
# 757                                                123
# ...

# %%
print("la media della pressione sanguigna diastolica nella fascia di età tra 20 e 30 è:", 
      int(pazienti.PressioneSanguignaDiastolica.loc[filtro20_30].mean()))
print("la media della pressione sanguigna diastolica nella fascia di età tra 30 e 40 è:", 
      int(pazienti.PressioneSanguignaDiastolica.loc[filtro30_40].mean()))
print("la media della pressione sanguigna diastolica nella fascia di età tra 40 e 50 è:", 
      int(pazienti.PressioneSanguignaDiastolica.loc[filtro40_50].mean()))
print("la media della pressione sanguigna diastolica nella fascia di età sopra i 50 è:", 
      int(pazienti.PressioneSanguignaDiastolica.loc[filtro50].mean()))
# Out:
# la media della pressione sanguigna diastolica nella fascia di età tra 20 e 30 è: 65
# la media della pressione sanguigna diastolica nella fascia di età tra 30 e 40 è: 69
# la media della pressione sanguigna diastolica nella fascia di età tra 40 e 50 è: 73
# la media della pressione sanguigna diastolica nella fascia di età sopra i 50 è: 78

# %%
mediapressionexeta = pazienti.groupby(["Eta"])
mediapressionexeta.PressioneSanguignaDiastolica.mean()
# Out:
# Eta
# 21    65.936508
# 22    63.722222
# 23    64.315789
# 24    64.956522
# 25    59.666667
# 26    64.181818
# 27    73.500000
# 28    68.314286
# 29    68.241379
# 30    64.857143
# 31    64.375000
# 32    70.062500
# 33    65.647059
# 34    74.000000
# 35    75.600000
# 36    69.125000
# 37    75.947368
# 38    71.125000
# 39    72.666667
# 40    69.230769
# 41    67.590909
# 42    73.388889
# 43    78.461538
# 44    61.750000
# 45    83.066667
# 46    76.000000
# 47    78.333333
# 48    78.400000
# 49    81.400000
# 50    78.250000
# 51    84.500000
# 52    81.500000
# 53    79.000000
# 54    89.333333
# 55    70.250000
# 56    76.333333
# 57    76.800000
# 58    78.285714
# 59    74.000000
# 60    80.000000
# 61    76.000000
# 62    71.500000
# 63    78.000000
# 64    78.000000
# 65    78.666667
# 66    86.000000
# 67    72.666667
# 68    82.000000
# 69    81.000000
# 70    82.000000
# 72     0.000000
# 81    74.000000
# Name: PressioneSanguignaDiastolica, dtype: float64

# %%
pazienti.iloc[:, -1].value_counts()
# Out:
# 0    500
# 1    268
# Name: Class variable, dtype: int64

# %%
pazienti.iloc[:, -1].value_counts(normalize=True)
# Out:
# 0    0.651042
# 1    0.348958
# Name: Class variable, dtype: float64

# %%
def codificaeta(eta):
    if eta < 20:
        return "<20"
    elif 20<= eta < 30:
        return "20-30"
    elif 30<= eta < 40:
        return "30-40"
    elif 40 <= eta <= 50:
        return "40-50"
    else:
        return ">50"

# %%
valore = 81
codificaeta(valore)
# Out:
# '>50'

# %%
pazienti.loc[:, "Fasciaeta"] = pazienti.loc

# %%
pazienti.loc[pazienti.Fasciaeta=="20-30"]

# %%
pazienti.groupby("Fasciaeta")[:, "Diagnostica"].mean()

# %%
pazienti.groupby("Age").mean()

# %%
abitanti = pd.read_csv("insurance.csv")

# %%
abitanti.shape
# Out:
# (1338, 7)

# %%
abitanti.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
abitanti
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
abitanti.sample(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 514    39    male  28.300         1    yes  southwest  21082.16000
# 275    47  female  26.600         2     no  northeast   9715.84100
# 454    32    male  46.530         2     no  southeast   4686.38870
# 764    45  female  25.175         2     no  northeast   9095.06825
# 176    38    male  27.835         2     no  northwest   6455.86265
# 717    60    male  24.320         1     no  northwest  13112.60480
# 1166   57    male  40.370         0     no  southeast  10982.50130
# 926    19  female  23.400         2     no  southwest   2913.56900
# 1158   20  female  30.590         0     no  northeast   2459.72010
# 307    30  female  33.330         1     no  southeast   4151.02870

# %%
mediaonerixregione = abitanti.groupby(["region"])
mediaonerixregione.charges.mean()
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %%
mediaonerixfumatore = abitanti.groupby(["smoker"])
mediaonerixfumatore.charges.mean()
# Out:
# smoker
# no      8434.268298
# yes    32050.231832
# Name: charges, dtype: float64

# %%
mediaonerixsesso = abitanti.groupby(["sex"])
mediaonerixsesso.charges.mean()
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %%
abitanti.bmi.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1338 entries, 0 to 1337
# Series name: bmi
# Non-Null Count  Dtype
# --------------  -----
# 1338 non-null   float64
# dtypes: float64(1)
# memory usage: 10.6 KB

# %%
abitanti.bmi.describe()
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %%
abitanti.sort_values("bmi", ascending=True, inplace=True)

# %%
abitanti
# Out:
#       age     sex     bmi  children smoker     region      charges
# 172    18    male  15.960         0     no  northeast   1694.79640
# 428    21  female  16.815         1     no  northeast   3167.45585
# 1226   38    male  16.815         2     no  northeast   6640.54485
# 412    26  female  17.195         2    yes  northeast  14455.64405
# 1286   28  female  17.290         0     no  northeast   3732.62510
# ...   ...     ...     ...       ...    ...        ...          ...
# 286    46  female  48.070         2     no  northeast   9432.92530
# 116    58    male  49.060         0     no  southeast  11381.32540
# 847    23    male  50.380         1     no  southeast   2438.05520
# 1047   22    male  52.580         1    yes  southeast  44501.39820
# 1317   18    male  53.130         0     no  southeast   1163.46270
#
# [1338 rows x 7 columns]

# %%
1338/4
# Out:
# 334.5

# %%
abitanti.loc[:334, "bmi"]
# Out:
# 172     15.960
# 428     16.815
# 1226    16.815
# 412     17.195
# 1286    17.290
#          ...
# 477     35.625
# 50      35.625
# 415     35.640
# 515     35.700
# 334     35.720
# Name: bmi, Length: 1058, dtype: float64

# %%
q1 = abitanti.bmi[334]

# %%
q1
# Out:
# 35.72

# %%
abitanti.groupby("region").mean().charges

# %%
abitanti.groupby("sex").mean().charges

# %%
abitanti.groupby("smoker").mean().charges

# %%
abitanti.bmi.describe()

# %%
pokemon = pd.read_csv("pokemon.csv")

# %%
pokemon.shape
# Out:
# (800, 13)

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon.sample(10)
# Out:
#        #                   Name    Type1    Type 2  Total   HP  Attack  \
# 279  257  BlazikenMega Blaziken     Fire  Fighting    630   80     160
# 250  231                 Phanpy   Ground       NaN    330   90      60
# 428  386     DeoxysNormal Forme  Psychic       NaN    600   50     150
# 54    49               Venomoth      Bug    Poison    450   70      65
# 481  433              Chingling  Psychic       NaN    285   45      30
# 429  386     DeoxysAttack Forme  Psychic       NaN    600   50     180
# 640  579              Reuniclus  Psychic       NaN    490  110      65
# 662  601              Klinklang    Steel       NaN    520   60     100
# 32    27              Sandshrew   Ground       NaN    300   50      75
# 246  228               Houndour     Dark      Fire    330   45      60
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 279       80      130       80    100           3      False
# 250       60       40       40     40           2      False
# ...

# %%
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pokemon.rename(columns={"Type 1": "Type1"},
                inplace= True)

# %%
pokemon.set_index("Name")
# Out:
#                          #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                1    Grass  Poison    318  45      49       49
# Ivysaur                  2    Grass  Poison    405  60      62       63
# Venusaur                 3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3    Grass  Poison    625  80     100      123
# Charmander               4     Fire     NaN    309  39      52       43
# ...                    ...      ...     ...    ...  ..     ...      ...
# Diancie                719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie    719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined    720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound     720  Psychic    Dark    680  80     160       60
# Volcanion              721     Fire   Water    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
pokemon.reset_index()
# Out:
#      index    #                   Name    Type1  Type 2  Total  HP  Attack  \
# 0        0    1              Bulbasaur    Grass  Poison    318  45      49
# 1        1    2                Ivysaur    Grass  Poison    405  60      62
# 2        2    3               Venusaur    Grass  Poison    525  80      82
# 3        3    3  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4        4    4             Charmander     Fire     NaN    309  39      52
# ..     ...  ...                    ...      ...     ...    ...  ..     ...
# 795    795  719                Diancie     Rock   Fairy    600  50     100
# 796    796  719    DiancieMega Diancie     Rock   Fairy    700  50     160
# 797    797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798    798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799    799  721              Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokemonunivoco = pokemon.groupby(["Name"])
pokemonunivoco.describe()
# Out:
#                             #                                                \
#                         count   mean std    min    25%    50%    75%    max
# Name
# Abomasnow                 1.0  460.0 NaN  460.0  460.0  460.0  460.0  460.0
# AbomasnowMega Abomasnow   1.0  460.0 NaN  460.0  460.0  460.0  460.0  460.0
# Abra                      1.0   63.0 NaN   63.0   63.0   63.0   63.0   63.0
# Absol                     1.0  359.0 NaN  359.0  359.0  359.0  359.0  359.0
# AbsolMega Absol           1.0  359.0 NaN  359.0  359.0  359.0  359.0  359.0
# ...                       ...    ...  ..    ...    ...    ...    ...    ...
# Zoroark                   1.0  571.0 NaN  571.0  571.0  571.0  571.0  571.0
# Zorua                     1.0  570.0 NaN  570.0  570.0  570.0  570.0  570.0
# Zubat                     1.0   41.0 NaN   41.0   41.0   41.0   41.0   41.0
# Zweilous                  1.0  634.0 NaN  634.0  634.0  634.0  634.0  634.0
# ...

# %%
pokemonunivoci = pokemon["Name"].unique()
pokemonunivoci
len(pokemonunivoci)
# Out:
# 800

# %%
pokemontype1 = pokemon.groupby(["Type1"])
pokemontype1.describe()
# Out:
#               #                                                               \
#           count        mean         std    min     25%    50%     75%    max
# Type1
# Bug        69.0  334.492754  210.445160   10.0  168.00  291.0  543.00  666.0
# Dark       31.0  461.354839  176.022072  197.0  282.00  509.0  627.00  717.0
# Dragon     32.0  474.375000  170.190169  147.0  373.00  443.5  643.25  718.0
# Electric   44.0  363.500000  202.731063   25.0  179.75  403.5  489.75  702.0
# Fairy      17.0  449.529412  271.983942   35.0  176.00  669.0  683.00  716.0
# Fighting   27.0  363.851852  218.565200   56.0  171.50  308.0  536.00  701.0
# Fire       52.0  327.403846  226.262840    4.0  143.50  289.5  513.25  721.0
# Flying      4.0  677.750000   42.437209  641.0  641.00  677.5  714.25  715.0
# Ghost      32.0  486.500000  209.189218   92.0  354.75  487.0  709.25  711.0
# Grass      70.0  344.871429  200.264385    1.0  187.25  372.0  496.75  673.0
# ...

# %%
pokemon_legendary = pokemon.Legendary == True

# %%
pokemon_legendary
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795     True
# 796     True
# 797     True
# 798     True
# 799     True
# Name: Legendary, Length: 800, dtype: bool

# %%
filtro_colonne = ["Name"]

# %%
pokemon_l = pokemon.loc[pokemon_legendary, filtro_colonne]

# %%
pokemon_l
# Out:
#                     Name
# 156             Articuno
# 157               Zapdos
# 158              Moltres
# 162               Mewtwo
# 163  MewtwoMega Mewtwo X
# ..                   ...
# 795              Diancie
# 796  DiancieMega Diancie
# 797  HoopaHoopa Confined
# 798   HoopaHoopa Unbound
# 799            Volcanion
#
# [65 rows x 1 columns]

# %%
filtro1 = pokemon["Type1"] = "Grass"

# %%
pokemon_legendarigrass = pokemon.loc[pokemon_legendary, filtro_colonne] & filtro1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:305, in na_logical_op(x, y, op)
#     296 try:
#     297     # For exposition, write:
#     298     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     303     # Then Cases where this goes through without raising include:
#     304     #  (xint or xbool) and (yint or bool)
# --> 305     result = op(x, y)
#     306 except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:319, in na_logical_op(x, y, op)
#     318 try:
# --> 319     result = libops.scalar_binop(x, y, op)
#     320 except (
# ...

# %%
pokemon.sort_values("Name")
# Out:
#        #                     Name  Type1  Type 2  Total   HP  Attack  Defense  \
# 510  460                Abomasnow  Grass     Ice    494   90      92       75
# 511  460  AbomasnowMega Abomasnow  Grass     Ice    594   90     132      105
# 68    63                     Abra  Grass     NaN    310   25      20       15
# 392  359                    Absol  Grass     NaN    465   65     130       60
# 393  359          AbsolMega Absol  Grass     NaN    565   65     150       60
# ..   ...                      ...    ...     ...    ...  ...     ...      ...
# 632  571                  Zoroark  Grass     NaN    510   60     105       60
# 631  570                    Zorua  Grass     NaN    330   40      65       40
# 46    41                    Zubat  Grass  Flying    245   40      45       35
# 695  634                 Zweilous  Grass  Dragon    420   72      85       70
# 794  718         Zygarde50% Forme  Grass  Ground    600  108     100      121
#
# ...

# %%
pokemon.set_index("Name")
# Out:
#                          #  Type1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                1  Grass  Poison    318  45      49       49
# Ivysaur                  2  Grass  Poison    405  60      62       63
# Venusaur                 3  Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3  Grass  Poison    625  80     100      123
# Charmander               4  Grass     NaN    309  39      52       43
# ...                    ...    ...     ...    ...  ..     ...      ...
# Diancie                719  Grass   Fairy    600  50     100      150
# DiancieMega Diancie    719  Grass   Fairy    700  50     160      110
# HoopaHoopa Confined    720  Grass   Ghost    600  80     110       60
# HoopaHoopa Unbound     720  Grass    Dark    680  80     160       60
# Volcanion              721  Grass   Water    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
filtroD = pokemon.Name.str.contains("D")

# %%
pokemon.loc[filtroD]
# Out:
#        #                     Name  Type1   Type 2  Total   HP  Attack  \
# 55    50                  Diglett  Grass      NaN    265   10      55
# 56    51                  Dugtrio  Grass      NaN    405   35      80
# 91    84                    Doduo  Grass   Flying    310   35      85
# 92    85                   Dodrio  Grass   Flying    460   60     110
# 94    87                  Dewgong  Grass      Ice    475   90      70
# 104   96                  Drowzee  Grass      NaN    328   60      48
# 143  132                    Ditto  Grass      NaN    288   48      48
# 159  147                  Dratini  Grass      NaN    300   41      64
# 160  148                Dragonair  Grass      NaN    420   61      84
# 161  149                Dragonite  Grass   Flying    600   91     134
# 221  206                Dunsparce  Grass      NaN    415  100      70
# 243  225                 Delibird  Grass   Flying    330   45      55
# ...

# %%
pokemon.loc[filtroD].describe()
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count   46.000000   46.000000   46.000000   46.000000   46.000000   46.000000
# mean   412.565217  445.043478   64.586957   83.130435   76.282609   72.673913
# std    211.412882  115.443677   24.668987   33.748487   34.976604   39.193001
# min     50.000000  265.000000   10.000000   30.000000   20.000000   15.000000
# 25%    226.750000  331.250000   50.000000   58.500000   50.000000   45.750000
# 50%    439.000000  439.500000   60.000000   75.000000   70.000000   60.000000
# 75%    579.500000  518.750000   75.000000  100.000000   93.750000   93.750000
# max    719.000000  700.000000  150.000000  180.000000  160.000000  180.000000
#
#           Sp. Def       Speed  Generation
# count   46.000000   46.000000   46.000000
# mean    73.586957   74.782609    3.608696
# std     31.916959   34.158398    1.782361
# min     20.000000   25.000000    1.000000
# 25%     50.000000   50.000000    2.000000
# ...

# %%
filtro1 = pokemon.loc[:,"Generation"] = "1"

# %%
filtro2 = pokemon.loc[:,"Attack"] > 50

# %%
filtro3 = pokemon.loc[:,"HP"] < 60

# %%
filtro = filtro1 & filtro2 & filtro3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:305, in na_logical_op(x, y, op)
#     296 try:
#     297     # For exposition, write:
#     298     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     303     # Then Cases where this goes through without raising include:
#     304     #  (xint or xbool) and (yint or bool)
# --> 305     result = op(x, y)
#     306 except TypeError:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# ...

# %%
pokemon.query("Generation == "1" and Attack >= 50 and HP <= 60")
# Out:
#   Cell In[53], line 1
#     pokemon.query("Generation == "1" and Attack >= 50 and HP <= 60")
#                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
pk1 = pokemon.loc[:5, ["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]]
pk1.sum(axis=1)
# Out:
# 0    318
# 1    405
# 2    525
# 3    625
# 4    309
# 5    405
# dtype: int64

# %%
pokemon.loc[:5, "Total"]
# Out:
# 0    318
# 1    405
# 2    525
# 3    625
# 4    309
# 5    405
# Name: Total, dtype: int64

# %%
pk1 = pokemon.loc[:, ["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]]

# %%
tot_sum = pk1.sum(axis=1) == pokemon.Total

# %%
tot_sum.sum()
# Out:
# 800

# %%
pokemon.set_index("#", inplace=True)

# %%
pokemon
# Out:
#                       Name    Type1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pokemon.loc[6]
# Out:
#                         Name Type1  Type 2  Total  HP  Attack  Defense  \
# #
# 6                  Charizard  Fire  Flying    534  78      84       78
# 6  CharizardMega Charizard X  Fire  Dragon    634  78     130      111
# 6  CharizardMega Charizard Y  Fire  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 6      109       85    100           1      False
# 6      130       85    100           1      False
# 6      159      115    100           1      False

# %%
lista_pokemon = list(pokemon.Name)
set_count = set()
for pokemon in pokemon.Name:
    numero_trovato = lista_pokemon.count(pokemon)
    set_count.add(numero_trovato)
    #print(lista_pokemon.count(pokemon))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 lista_pokemon = list(pokemon.Name)
#       2 set_count = set()
#       3 for pokemon in pokemon.Name:
#
# AttributeError: 'str' object has no attribute 'Name'

# %%
pokemon
# Out:
#        #                   Name    Type1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
import re
s = set()
for x in amazon.TestoRecensione:
    [s.add(k) for k in re.findall(("[Kk].?", x)

# %%
pokemon.loc[:, "Type1"].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type1, dtype: int64

# %%
pokemon.loc[:, "Type 2"].value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
pokemon.loc[pokemon.Legendary, "Name"]
# Out:
# 156               Articuno
# 157                 Zapdos
# 158                Moltres
# 162                 Mewtwo
# 163    MewtwoMega Mewtwo X
#               ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
# Name: Name, Length: 65, dtype: object

# %%
for name in pokemon.loc[pokemon.Legendary, "Name"].sort_values():
    print(name)
# Out:
# Arceus
# Articuno
# Azelf
# Cobalion
# Darkrai
# DeoxysAttack Forme
# DeoxysDefense Forme
# DeoxysNormal Forme
# DeoxysSpeed Forme
# Dialga
# Diancie
# DiancieMega Diancie
# Entei
# GiratinaAltered Forme
# GiratinaOrigin Forme
# Groudon
# GroudonPrimal Groudon
# Heatran
# Ho-oh
# HoopaHoopa Confined
# HoopaHoopa Unbound
# Jirachi
# Kyogre
# KyogrePrimal Kyogre
# Kyurem
# KyuremBlack Kyurem
# KyuremWhite Kyurem
# LandorusIncarnate Forme
# LandorusTherian Forme
# Latias
# LatiasMega Latias
# Latios
# LatiosMega Latios
# Lugia
# Mesprit
# Mewtwo
# MewtwoMega Mewtwo X
# MewtwoMega Mewtwo Y
# Moltres
# Palkia
# Raikou
# Rayquaza
# RayquazaMega Rayquaza
# Regice
# Regigigas
# Regirock
# Registeel
# Reshiram
# ShayminLand Forme
# ShayminSky Forme
# Suicune
# Terrakion
# ThundurusIncarnate Forme
# ThundurusTherian Forme
# TornadusIncarnate Forme
# TornadusTherian Forme
# Uxie
# Victini
# Virizion
# Volcanion
# Xerneas
# Yveltal
# Zapdos
# Zekrom
# Zygarde50% Forme

# %%
filtro = (pokemon.loc[:, "Type1"] == "Grass") & '''onda'''pokemon.Legendary
pokemon.loc[filtro, "Name"]
# Out:
# 550    ShayminLand Forme
# 551     ShayminSky Forme
# 701             Virizion
# Name: Name, dtype: object

# %%
filtro = (pokemon.loc[:, "Type1"] == "Grass") | (pokemon.loc[:, "Type 1"] == "Fire")
pokemon.loc[filtro, "Name"].sort_values()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Type 1'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
filtro = (pokemon.loc[:, "Type1"] == "Ice") | (pokemon.loc[:, "Type 1"] == "Fire")
filtro = filtro & pokemon.Legendary
pokemon.loc[filtro]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Type 1'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
pokemon.set_index("Name", inplace=True)
pokemon
# Out:
#                          #    Type1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                1    Grass  Poison    318  45      49       49
# Ivysaur                  2    Grass  Poison    405  60      62       63
# Venusaur                 3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3    Grass  Poison    625  80     100      123
# Charmander               4     Fire     NaN    309  39      52       43
# ...                    ...      ...     ...    ...  ..     ...      ...
# Diancie                719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie    719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined    720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound     720  Psychic    Dark    680  80     160       60
# Volcanion              721     Fire   Water    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
[nome for nome in pokemon.index if nome[0] == "D"]
# Out:
# ['Diglett',
#  'Dugtrio',
#  'Doduo',
#  'Dodrio',
#  'Dewgong',
#  'Drowzee',
#  'Ditto',
#  'Dratini',
#  'Dragonair',
#  'Dragonite',
#  'Dunsparce',
#  'Delibird',
#  'Donphan',
#  'Dustox',
#  'Delcatty',
#  'Duskull',
#  'Dusclops',
#  'DeoxysNormal Forme',
#  'DeoxysAttack Forme',
#  'DeoxysDefense Forme',
#  'DeoxysSpeed Forme',
#  'Drifloon',
#  'Drifblim',
#  'Drapion',
#  'Dusknoir',
#  'Dialga',
#  'Darkrai',
#  'Dewott',
#  'Drilbur',
#  'Darumaka',
#  'DarmanitanStandard Mode',
#  'DarmanitanZen Mode',
#  'Dwebble',
#  'Duosion',
#  'Ducklett',
#  'Deerling',
#  'Druddigon',
#  'Durant',
#  'Deino',
#  'Delphox',
#  'Diggersby',
#  'Doublade',
#  'Dragalge',
#  'Dedenne',
#  'Diancie',
#  'DiancieMega Diancie']

# %%
pokemon.loc["Darkrai":"Dwe

# %%
nomiinizd = [nome for nome in pokemon.index if nome[0] == "D"]

# %%
pokemon.loc[nomiinizd[0]:nomiinizd[-1]]
# Out:
#                        #   Type1  Type 2  Total   HP  Attack  Defense  \
# Name
# Diglett               50  Ground     NaN    265   10      55       25
# Dugtrio               51  Ground     NaN    405   35      80       50
# Meowth                52  Normal     NaN    290   40      45       35
# Persian               53  Normal     NaN    440   65      70       60
# Psyduck               54   Water     NaN    320   50      52       48
# ...                  ...     ...     ...    ...  ...     ...      ...
# Xerneas              716   Fairy     NaN    680  126     131       95
# Yveltal              717    Dark  Flying    680  126     131       95
# Zygarde50% Forme     718  Dragon  Ground    600  108     100      121
# Diancie              719    Rock   Fairy    600   50     100      150
# DiancieMega Diancie  719    Rock   Fairy    700   50     160      110
#
#                      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
nomiiniz = [nome for nome in pokemon.index if nome[0] == "E"]
pokemon.loc[nomiiniz[0]:nomiiniz[-1]]
# Out:
#              #     Type1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Ekans       23    Poison    NaN    288   35      60       44       40
# Arbok       24    Poison    NaN    438   60      85       69       65
# Pikachu     25  Electric    NaN    320   35      55       40       50
# Raichu      26  Electric    NaN    485   60      90       55       90
# Sandshrew   27    Ground    NaN    300   50      75       85       20
# ...        ...       ...    ...    ...  ...     ...      ...      ...
# Gogoat     673     Grass    NaN    531  123     100       62       97
# Pancham    674  Fighting    NaN    348   67      82       62       46
# Pangoro    675  Fighting   Dark    495   95     124       78       69
# Furfrou    676    Normal    NaN    472   75      80       60       65
# Espurr     677   Psychic    NaN    355   62      48       54       63
#
#            Sp. Def  Speed  Generation  Legendary
# Name
# Ekans           54     55           1      False
# ...

# %%
filtro1 = pokemon.Attack > 50
filtro2 = pokemon.HP < 60
filtro3 = pokemon.Generation == 1
filtro = filtro1 & filtro2 & filtro3
pokemon.loc[filtro]
# Out:
#               #     Type1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Charmander    4      Fire     NaN    309  39      52       43       60
# Charmeleon    5      Fire     NaN    405  58      64       58       80
# Wartortle     8     Water     NaN    405  59      63       80       65
# Rattata      19    Normal     NaN    253  30      56       35       25
# Raticate     20    Normal     NaN    413  55      81       60       50
# Spearow      21    Normal  Flying    262  40      60       30       31
# Ekans        23    Poison     NaN    288  35      60       44       40
# Pikachu      25  Electric     NaN    320  35      55       40       50
# Sandshrew    27    Ground     NaN    300  50      75       85       20
# Nidoran♂     32    Poison     NaN    273  46      57       40       40
# Paras        46       Bug   Grass    285  35      70       55       45
# Diglett      50    Ground     NaN    265  10      55       25       35
# ...

# %%
filtro1 = pokemon.Attack > 50
filtro2 = pokemon.HP < 60
filtro3 = pokemon.Generation == 1
filtro4 = pokemon.Speed == 70
filtro = filtro1 & filtro2 & filtro3 & filtro4
pokemon.loc[filtro]
# Out:
#            #     Type1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Spearow   21    Normal  Flying    262  40      60       30       31       31
# Mankey    56  Fighting     NaN    305  40      80       35       35       45
# Magneton  82  Electric   Steel    465  50      60       95      120       70
# Cloyster  91     Water     Ice    525  50      95      180       85       45
#
#           Speed  Generation  Legendary
# Name
# Spearow      70           1      False
# Mankey       70           1      False
# Magneton     70           1      False
# Cloyster     70           1      False

# %%
pokemon.isnull().sum()
# Out:
# #               0
# Type1           0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
filtro = pokemon.loc[:, "Type 2"].isnull()
pokemon.loc[filtro]
# Out:
#               #   Type1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Charmander    4    Fire    NaN    309   39      52       43       60       50
# Charmeleon    5    Fire    NaN    405   58      64       58       80       65
# Squirtle      7   Water    NaN    314   44      48       65       50       64
# Wartortle     8   Water    NaN    405   59      63       80       65       80
# Blastoise     9   Water    NaN    530   79      83      100       85      105
# ...         ...     ...    ...    ...  ...     ...      ...      ...      ...
# Sliggoo     705  Dragon    NaN    452   68      75       53       83      113
# Goodra      706  Dragon    NaN    600   90     100       70      110      150
# Bergmite    712     Ice    NaN    304   55      69       85       32       35
# Avalugg     713     Ice    NaN    514   95     117      184       44       46
# Xerneas     716   Fairy    NaN    680  126     131       95      131       98
#
# ...

# %%
filtro = pokemon.loc[:, "Type 2"].isnull()
pokemon.loc[filtro].Generation.value_counts()
# Out:
# 1    88
# 5    83
# 3    78
# 4    54
# 2    51
# 6    32
# Name: Generation, dtype: int64
